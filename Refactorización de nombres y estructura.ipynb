# %% [markdown]
# # ⚠️ Código Heredado
# **Instrucciones:** Este script funciona a nivel de máquina, pero incumple todas las buenas prácticas de un profesional.
#
# Encuentra los problemas, refactorízalo (pon nombres lógicos, agrupa los imports arriba del todo, añade docstrings, elimina funciones duplicadas, respeta los espacios del PEP8) y súbelo a tu repositorio de GitHub.

# %%
"""
Módulo de Procesamiento de Biomarcadores

Autor: Tatiana
Descripción:
Script refactorizado siguiendo estándares PEP8.
"""

# Imports al inicio
import pandas as pd
import numpy as np


def calcular_suma_biomarcadores(valor_a, valor_b):
    """
    Suma dos biomarcadores clínicos.

    Args:
        valor_a: Primer biomarcador.
        valor_b: Segundo biomarcador.

    Returns:
        Resultado de la suma.
    """
    return valor_a + valor_b


# Carga de datos
datos_laboratorio = pd.read_csv("datos.csv")

# Variables descriptivas
hemoglobina = datos_laboratorio["col1"]
creatinina = datos_laboratorio["col2"]

# Procesamiento
resultado_analisis = calcular_suma_biomarcadores(
    hemoglobina,
    creatinina
)

print("Procesamiento completado con éxito.")
